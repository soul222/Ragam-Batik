# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import os
from collections import defaultdict
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from ipywidgets import FileUpload, Output
from IPython.display import display

# paths and parameters
TRAIN_DIR = "DATASET/TRAIN/"
TEST_DIR = "DATASET/TEST/"
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
BATCH_SIZE = 16
EPOCHS_INITIAL = 45
EPOCHS_FINE_TUNE = 20
MODEL_DIR = "./model_testing"
CHECKPOINT_FILE = "model_testing_1.keras"
CHECKPOINT_PATH = os.path.join(MODEL_DIR, CHECKPOINT_FILE)
LEARNING_RATE_FINE_TUNE = 1e-5

# Create model directory if not exists
os.makedirs(MODEL_DIR, exist_ok=True)
# Out:
# 2024-12-10 22:23:57.292588: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-10 22:23:57.488769: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733844237.557613     838 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733844237.574315     838 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-10 22:23:57.722157: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.25,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode="nearest",
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle="True"
)

validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)
# Out:
# Found 688 images belonging to 26 classes.
# Found 159 images belonging to 26 classes.
# Found 208 images belonging to 26 classes.

# %%
from tensorflow.keras.regularizers import l2
base_model = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3)
)

# Build the model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output_layer = Dense(
    train_generator.num_classes,
    activation="softmax",
    kernel_regularizer=l2(1e-4),
)(x)

model = Model(inputs=base_model.input, outputs=output_layer)

# Freeze some of the deeper base model layers
for layer in base_model.layers[:120]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# Load checkpoint if exists
if os.path.exists(CHECKPOINT_PATH):
    print("Checkpoint found. Loading model...")
    model = tf.keras.models.load_model(CHECKPOINT_PATH)
else:
    print("No checkpoint found. Training model from scratch...")
# Out:
# Checkpoint found. Loading model...

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ keras_tensor_1753CLONE          │ (None, 7, 7, 1280)     │             0 │
# │ (InputLayer)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 26)             │         6,682 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 340,762 (1.30 MB)
#  Trainable params: 337,690 (1.29 MB)
#  Non-trainable params: 3,072 (12.00 KB)

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=8),
    ModelCheckpoint(CHECKPOINT_PATH, monitor="val_accuracy", save_best_only=True, save_weights_only=False, verbose=1),
]

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS_INITIAL,
    validation_data=validation_generator,
    callbacks=callbacks,
)

# Fine-tuning
fine_tune_at = 200  # Unfreeze layers from 200 onwards
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
for layer in base_model.layers[fine_tune_at:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_fine_tune = model.fit(
    train_generator,
    epochs=EPOCHS_FINE_TUNE,
    validation_data=validation_generator,
    callbacks=callbacks,
)
# Out:
# /root/dev/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/45
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733236164.155658   10332 service.cc:148] XLA service 0x7f44040678c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733236164.155722   10332 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2024-12-03 21:29:24.483795: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1733236165.717147   10332 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1733236178.975123   10332 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1733236179.330341   10332 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1733236188.286343   10332 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.1637 - loss: 3.6417
# /root/dev/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.46541, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 52s 439ms/step - accuracy: 0.1662 - loss: 3.6277 - val_accuracy: 0.4654 - val_loss: 2.1428 - learning_rate: 0.0010
# Epoch 2/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5100 - loss: 1.8183
# Epoch 2: val_accuracy improved from 0.46541 to 0.60377, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.5104 - loss: 1.8174 - val_accuracy: 0.6038 - val_loss: 1.5724 - learning_rate: 0.0010
# Epoch 3/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6688 - loss: 1.2282
# Epoch 3: val_accuracy did not improve from 0.60377
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.6684 - loss: 1.2289 - val_accuracy: 0.6038 - val_loss: 1.6409 - learning_rate: 0.0010
# Epoch 4/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7305 - loss: 0.8855
# Epoch 4: val_accuracy improved from 0.60377 to 0.67296, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.7301 - loss: 0.8879 - val_accuracy: 0.6730 - val_loss: 1.3843 - learning_rate: 0.0010
# Epoch 5/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8005 - loss: 0.7503
# Epoch 5: val_accuracy improved from 0.67296 to 0.75472, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.8006 - loss: 0.7497 - val_accuracy: 0.7547 - val_loss: 1.0385 - learning_rate: 0.0010
# Epoch 6/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8477 - loss: 0.5688
# Epoch 6: val_accuracy did not improve from 0.75472
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8471 - loss: 0.5710 - val_accuracy: 0.6730 - val_loss: 1.5098 - learning_rate: 0.0010
# Epoch 7/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8635 - loss: 0.5429
# Epoch 7: val_accuracy improved from 0.75472 to 0.76101, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8631 - loss: 0.5437 - val_accuracy: 0.7610 - val_loss: 1.2545 - learning_rate: 0.0010
# Epoch 8/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8994 - loss: 0.4256
# Epoch 8: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.8992 - loss: 0.4266 - val_accuracy: 0.7547 - val_loss: 1.2595 - learning_rate: 0.0010
# Epoch 9/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8950 - loss: 0.4247
# Epoch 9: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.8945 - loss: 0.4257 - val_accuracy: 0.7610 - val_loss: 1.0304 - learning_rate: 0.0010
# Epoch 10/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8799 - loss: 0.4833
# Epoch 10: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8800 - loss: 0.4824 - val_accuracy: 0.7358 - val_loss: 1.2404 - learning_rate: 0.0010
# Epoch 11/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9163 - loss: 0.3167
# Epoch 11: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9160 - loss: 0.3178 - val_accuracy: 0.6981 - val_loss: 1.9112 - learning_rate: 0.0010
# Epoch 12/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9185 - loss: 0.3761
# Epoch 12: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9183 - loss: 0.3772 - val_accuracy: 0.7484 - val_loss: 1.4608 - learning_rate: 0.0010
# Epoch 13/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9086 - loss: 0.3682
# Epoch 13: val_accuracy did not improve from 0.76101
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9086 - loss: 0.3685 - val_accuracy: 0.7296 - val_loss: 1.3964 - learning_rate: 0.0010
# Epoch 14/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9216 - loss: 0.3138
# Epoch 14: val_accuracy improved from 0.76101 to 0.78616, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9214 - loss: 0.3146 - val_accuracy: 0.7862 - val_loss: 1.0773 - learning_rate: 0.0010
# Epoch 15/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9448 - loss: 0.2851
# Epoch 15: val_accuracy improved from 0.78616 to 0.79874, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9446 - loss: 0.2849 - val_accuracy: 0.7987 - val_loss: 1.0783 - learning_rate: 0.0010
# Epoch 16/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9243 - loss: 0.3167
# Epoch 16: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9242 - loss: 0.3176 - val_accuracy: 0.7736 - val_loss: 1.2923 - learning_rate: 0.0010
# Epoch 17/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9215 - loss: 0.3004
# Epoch 17: val_accuracy did not improve from 0.79874
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9218 - loss: 0.2996 - val_accuracy: 0.7799 - val_loss: 1.0283 - learning_rate: 0.0010
# Epoch 18/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9410 - loss: 0.2436
# Epoch 18: val_accuracy improved from 0.79874 to 0.81132, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9410 - loss: 0.2440 - val_accuracy: 0.8113 - val_loss: 1.0654 - learning_rate: 0.0010
# Epoch 19/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9269 - loss: 0.3467
# Epoch 19: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9270 - loss: 0.3463 - val_accuracy: 0.7421 - val_loss: 1.2287 - learning_rate: 0.0010
# Epoch 20/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9391 - loss: 0.2498
# Epoch 20: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9391 - loss: 0.2506 - val_accuracy: 0.7610 - val_loss: 1.3939 - learning_rate: 0.0010
# Epoch 21/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9301 - loss: 0.2821
# Epoch 21: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9302 - loss: 0.2820 - val_accuracy: 0.7736 - val_loss: 1.1330 - learning_rate: 0.0010
# Epoch 22/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9611 - loss: 0.2026
# Epoch 22: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9611 - loss: 0.2027 - val_accuracy: 0.7673 - val_loss: 0.9481 - learning_rate: 0.0010
# Epoch 23/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9490 - loss: 0.2266
# Epoch 23: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9491 - loss: 0.2266 - val_accuracy: 0.7736 - val_loss: 1.1067 - learning_rate: 0.0010
# Epoch 24/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9410 - loss: 0.2329
# Epoch 24: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9411 - loss: 0.2330 - val_accuracy: 0.7547 - val_loss: 0.9805 - learning_rate: 0.0010
# Epoch 25/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9597 - loss: 0.2321
# Epoch 25: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9597 - loss: 0.2311 - val_accuracy: 0.7358 - val_loss: 1.0987 - learning_rate: 0.0010
# Epoch 26/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9671 - loss: 0.1993
# Epoch 26: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9669 - loss: 0.2003 - val_accuracy: 0.7925 - val_loss: 0.9977 - learning_rate: 0.0010
# Epoch 27/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9493 - loss: 0.2734
# Epoch 27: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9493 - loss: 0.2736 - val_accuracy: 0.7799 - val_loss: 1.1285 - learning_rate: 0.0010
# Epoch 28/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9692 - loss: 0.1870
# Epoch 28: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9688 - loss: 0.1881 - val_accuracy: 0.7610 - val_loss: 1.2181 - learning_rate: 0.0010
# Epoch 29/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9570 - loss: 0.2018
# Epoch 29: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9570 - loss: 0.2022 - val_accuracy: 0.7925 - val_loss: 1.0280 - learning_rate: 0.0010
# Epoch 30/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9543 - loss: 0.2238
# Epoch 30: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9544 - loss: 0.2234 - val_accuracy: 0.7925 - val_loss: 1.0618 - learning_rate: 0.0010
# Epoch 31/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9496 - loss: 0.2250
# Epoch 31: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9498 - loss: 0.2245 - val_accuracy: 0.8050 - val_loss: 0.8419 - learning_rate: 5.0000e-04
# Epoch 32/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9776 - loss: 0.1396
# Epoch 32: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9776 - loss: 0.1396 - val_accuracy: 0.8113 - val_loss: 0.9310 - learning_rate: 5.0000e-04
# Epoch 33/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9863 - loss: 0.1116
# Epoch 33: val_accuracy did not improve from 0.81132
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9862 - loss: 0.1118 - val_accuracy: 0.8050 - val_loss: 0.9562 - learning_rate: 5.0000e-04
# Epoch 34/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9714 - loss: 0.1618
# Epoch 34: val_accuracy improved from 0.81132 to 0.81761, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9715 - loss: 0.1614 - val_accuracy: 0.8176 - val_loss: 0.8576 - learning_rate: 5.0000e-04
# Epoch 35/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9846 - loss: 0.1068
# Epoch 35: val_accuracy improved from 0.81761 to 0.83019, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9846 - loss: 0.1068 - val_accuracy: 0.8302 - val_loss: 0.8512 - learning_rate: 5.0000e-04
# Epoch 36/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9936 - loss: 0.1048
# Epoch 36: val_accuracy did not improve from 0.83019
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9934 - loss: 0.1052 - val_accuracy: 0.8176 - val_loss: 0.7653 - learning_rate: 5.0000e-04
# Epoch 37/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9960 - loss: 0.0910
# Epoch 37: val_accuracy improved from 0.83019 to 0.86792, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9959 - loss: 0.0911 - val_accuracy: 0.8679 - val_loss: 0.7219 - learning_rate: 5.0000e-04
# Epoch 38/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9894 - loss: 0.0942
# Epoch 38: val_accuracy did not improve from 0.86792
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9892 - loss: 0.0945 - val_accuracy: 0.8302 - val_loss: 0.6691 - learning_rate: 5.0000e-04
# Epoch 39/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9846 - loss: 0.0960
# Epoch 39: val_accuracy did not improve from 0.86792
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9848 - loss: 0.0958 - val_accuracy: 0.8302 - val_loss: 0.9306 - learning_rate: 5.0000e-04
# Epoch 40/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9899 - loss: 0.0939
# Epoch 40: val_accuracy did not improve from 0.86792
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9900 - loss: 0.0939 - val_accuracy: 0.8553 - val_loss: 0.7141 - learning_rate: 5.0000e-04
# Epoch 41/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9773 - loss: 0.1215
# Epoch 41: val_accuracy did not improve from 0.86792
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9774 - loss: 0.1213 - val_accuracy: 0.8679 - val_loss: 0.7705 - learning_rate: 5.0000e-04
# Epoch 42/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9851 - loss: 0.0935
# Epoch 42: val_accuracy did not improve from 0.86792
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9853 - loss: 0.0933 - val_accuracy: 0.8679 - val_loss: 0.7614 - learning_rate: 5.0000e-04
# Epoch 43/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9931 - loss: 0.0996
# Epoch 43: val_accuracy improved from 0.86792 to 0.88679, saving model to ./model_testing/model_testing_1.keras
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.9930 - loss: 0.0997 - val_accuracy: 0.8868 - val_loss: 0.6575 - learning_rate: 5.0000e-04
# Epoch 44/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9856 - loss: 0.0949
# Epoch 44: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9856 - loss: 0.0950 - val_accuracy: 0.8679 - val_loss: 0.7732 - learning_rate: 5.0000e-04
# Epoch 45/45
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9914 - loss: 0.0835
# Epoch 45: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9914 - loss: 0.0837 - val_accuracy: 0.8428 - val_loss: 0.7879 - learning_rate: 5.0000e-04
# Epoch 1/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9989 - loss: 0.0703
# Epoch 1: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 22s 212ms/step - accuracy: 0.9989 - loss: 0.0704 - val_accuracy: 0.8616 - val_loss: 0.6749 - learning_rate: 1.0000e-05
# Epoch 2/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9908 - loss: 0.0778
# Epoch 2: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9908 - loss: 0.0779 - val_accuracy: 0.8616 - val_loss: 0.7389 - learning_rate: 1.0000e-05
# Epoch 3/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9931 - loss: 0.0846
# Epoch 3: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9930 - loss: 0.0847 - val_accuracy: 0.8679 - val_loss: 0.6245 - learning_rate: 1.0000e-05
# Epoch 4/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9973 - loss: 0.0720
# Epoch 4: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9972 - loss: 0.0721 - val_accuracy: 0.8553 - val_loss: 0.6118 - learning_rate: 1.0000e-05
# Epoch 5/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9862 - loss: 0.0947
# Epoch 5: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9863 - loss: 0.0946 - val_accuracy: 0.8491 - val_loss: 0.6998 - learning_rate: 1.0000e-05
# Epoch 6/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9948 - loss: 0.0765
# Epoch 6: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9947 - loss: 0.0767 - val_accuracy: 0.8679 - val_loss: 0.7394 - learning_rate: 1.0000e-05
# Epoch 7/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9951 - loss: 0.0764
# Epoch 7: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9951 - loss: 0.0765 - val_accuracy: 0.8679 - val_loss: 0.7091 - learning_rate: 1.0000e-05
# Epoch 8/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9939 - loss: 0.0807
# Epoch 8: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9938 - loss: 0.0807 - val_accuracy: 0.8679 - val_loss: 0.6251 - learning_rate: 1.0000e-05
# Epoch 9/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9953 - loss: 0.0754
# Epoch 9: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9953 - loss: 0.0754 - val_accuracy: 0.8616 - val_loss: 0.6753 - learning_rate: 1.0000e-05
# Epoch 10/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9983 - loss: 0.0779
# Epoch 10: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9982 - loss: 0.0780 - val_accuracy: 0.8302 - val_loss: 0.7535 - learning_rate: 1.0000e-05
# Epoch 11/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9950 - loss: 0.0725
# Epoch 11: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9949 - loss: 0.0726 - val_accuracy: 0.8491 - val_loss: 0.7346 - learning_rate: 1.0000e-05
# Epoch 12/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9928 - loss: 0.0829
# Epoch 12: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9928 - loss: 0.0828 - val_accuracy: 0.8616 - val_loss: 0.6905 - learning_rate: 1.0000e-05
# Epoch 13/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9937 - loss: 0.0891
# Epoch 13: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9937 - loss: 0.0890 - val_accuracy: 0.8428 - val_loss: 0.6996 - learning_rate: 5.0000e-06
# Epoch 14/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9949 - loss: 0.0739
# Epoch 14: val_accuracy did not improve from 0.88679
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9950 - loss: 0.0738 - val_accuracy: 0.8616 - val_loss: 0.7134 - learning_rate: 5.0000e-06

# %%
validation_loss, validation_accuracy = model.evaluate(validation_generator)
print(f"Validation Loss: {validation_loss:.3f}, Validation Accuracy: {validation_accuracy:.2%}")

test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.3f}, Test Accuracy: {test_accuracy:.2%}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9031 - loss: 0.5790
# Validation Loss: 0.597, Validation Accuracy: 89.31%
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8880 - loss: 0.6072
# Test Loss: 0.652, Test Accuracy: 87.50%

# %%
predictions = model.predict(test_generator)
class_labels = list(test_generator.class_indices.keys())
true_indices = test_generator.classes
predicted_indices = np.argmax(predictions, axis=1)
prediction_confidences = np.max(predictions, axis=1)

# Visualization function
def visualize_predictions(indices, title, rows=2, cols=5):
    fig, axes = plt.subplots(rows, cols, figsize=(15, 6))
    for i, idx in enumerate(indices):
        img_path = test_generator.filepaths[idx]
        img = plt.imread(img_path)
        true_label = class_labels[true_indices[idx]]
        predicted_label = class_labels[predicted_indices[idx]]
        confidence = prediction_confidences[idx] * 100

        ax = axes[i // cols, i % cols]
        ax.imshow(img)
        ax.axis("off")
        ax.set_title(f"True: {true_label}\nPred: {predicted_label}\nConf: {confidence:.2f}%", fontsize=10)

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# Lowest and highest confidence predictions
low_conf_indices = np.argsort(prediction_confidences)[:10]
high_conf_indices = np.argsort(prediction_confidences)[-10:][::-1]

visualize_predictions(low_conf_indices, "Lowest 10 Predictions by Confidence")
visualize_predictions(high_conf_indices, "Top 10 Predictions by Confidence")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step

# %%
def evaluate_by_folder(generator, predictions):
    folder_results = defaultdict(lambda: {"correct": 0, "total": 0})
    predicted_indices = np.argmax(predictions, axis=1)

    for filepath, true_idx, pred_idx in zip(generator.filepaths, generator.classes, predicted_indices):
        folder = os.path.basename(os.path.dirname(filepath))
        folder_results[folder]["total"] += 1
        if true_idx == pred_idx:
            folder_results[folder]["correct"] += 1

    return {folder: f"{result['correct']}/{result['total']}" for folder, result in folder_results.items()}

folder_results = evaluate_by_folder(test_generator, predictions)
print("Folder-wise Evaluation Results:")
for folder, result in folder_results.items():
    print(f"{folder}: {result}")
# Out:
# Folder-wise Evaluation Results:
# Aceh_Pintu_Aceh: 7/8
# Bali_Barong: 8/8
# Bali_Merak: 8/8
# DKI_Ondel_Ondel: 6/8
# Jawa_Barat_Megamendung: 8/8
# Jawa_Tengah_Batik_Lasem: 7/8
# Jawa_Timur_Pring: 7/8
# Kalimantan_Barat_Insang: 6/8
# Kalimantan_Dayak: 8/8
# Lampung_Gajah: 5/8
# Madura_Mataketeran: 7/8
# Maluku_Pala: 8/8
# NTB_Lumbung: 8/8
# Palembang_Songket: 6/8
# Papua_Asmat: 6/8
# Papua_Cendrawasih: 7/8
# Papua_Tifa: 7/8
# Solo_Parang: 8/8
# Solo_Sidoluhur: 7/8
# Solo_Sogan: 6/8
# Solo_Truntum: 7/8
# Sulawesi_Selatan_Lontara: 7/8
# Sumatera_Barat_Rumah_Minang: 8/8
# Sumatera_Utara_Boraspati: 7/8
# Yogyakarta_Kawung: 8/8
# Yogyakarta_Sidomukti: 5/8

# %%
output = Output()
upload_widget = FileUpload(accept="image/*", multiple=False)
class_labels = list(test_generator.class_indices.keys())

def handle_upload(change):
    output.clear_output()
    with output:
        # Check if a file is uploaded
        if not upload_widget.value:
            print("Please upload an image file.")
            return
        
        # Access uploaded file content
        try:
            # If upload_widget.value is a dict
            if isinstance(upload_widget.value, dict):
                file = list(upload_widget.value.values())[0]
            # If upload_widget.value is a list or tuple
            elif isinstance(upload_widget.value, (list, tuple)):
                file = upload_widget.value[0]
            else:
                print("Unsupported upload format.")
                return

            temp_path = "./uploaded_image.jpg"
            
            # Save the file to a temporary location
            with open(temp_path, "wb") as f:
                f.write(file["content"])
            
            # Load the model from the checkpoint
            if os.path.exists(CHECKPOINT_PATH):
                print("Loading model from checkpoint...")
                loaded_model = tf.keras.models.load_model(CHECKPOINT_PATH)
            else:
                print("No checkpoint found. Ensure the model is trained and checkpoint exists.")
                return
            
            # Load and preprocess the uploaded image
            img = load_img(temp_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
            img_array = img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array = preprocess_input(img_array) 
            
            # Make prediction
            preds = loaded_model.predict(img_array)
            predicted_idx = np.argmax(preds)
            confidence = preds[0][predicted_idx] * 100
            predicted_label = class_labels[predicted_idx]
            
            # Display the uploaded image with prediction result
            plt.figure(figsize=(6, 6))
            img_display = plt.imread(temp_path)
            plt.imshow(img_display)
            plt.axis("off")
            plt.title(f"Prediction: {predicted_label}\nConfidence: {confidence:.2f}%", fontsize=14)
            plt.show()
        
        except Exception as e:
            # Catch and display any errors
            print(f"Error during processing: {str(e)}")

# Observe the upload widget
upload_widget.observe(handle_upload, names="value")
display(upload_widget, output)
# Out:
# FileUpload(value=(), accept='image/*', description='Upload')
# Output()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Initial Train Loss")
plt.plot(history.history["val_loss"], label="Initial Val Loss")
plt.plot(history_fine_tune.history["loss"], label="Fine-tune Train Loss")
plt.plot(history_fine_tune.history["val_loss"], label="Fine-tune Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Initial Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Initial Val Accuracy")
plt.plot(history_fine_tune.history["accuracy"], label="Fine-tune Train Accuracy")
plt.plot(history_fine_tune.history["val_accuracy"], label="Fine-tune Val Accuracy")
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
# Path to the .keras model
keras_model_path = CHECKPOINT_PATH
model = tf.keras.models.load_model(keras_model_path)

# Save the model in the SavedModel format
model.export("model_testing_sm")


# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()


# with open("converted_model.tflite", "wb") as f:
#     f.write(tflite_model)

# print("Model successfully converted to TFLite format!")
# model.export("models")

# # Path to save the .h5 model
# h5_model_path = os.path.join(MODEL_DIR, "final_model_h.h5")

# # Step 1: Load the .keras model
# model = tf.keras.models.load_model(keras_model_path)
# print("Model loaded successfully.")

# # Step 2: Save the model in .h5 format
# model.save(h5_model_path, save_format="tf")
# print(f"Model saved successfully to {h5_model_path}.")
# Out:
# INFO:tensorflow:Assets written to: model_testing_sm/assets
# INFO:tensorflow:Assets written to: model_testing_sm/assets
# Saved artifact at 'model_testing_sm'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 26), dtype=tf.float32, name=None)
# Captures:
#   139983060107728: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139983060112720: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   139979698613200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698614736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698614544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698614352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698615696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698617424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698614160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698617232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698617616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698618000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697456528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697456912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697460752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697461520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697460176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697462672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697463056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697463824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697464976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697463440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697464208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697468816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697470544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697469392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697864976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697865744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697471120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697865360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698611280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697867280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957786320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979698612048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697867088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697866704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697864784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697870736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697871504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697872848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697875344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697876112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697874768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697877264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697876688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697877648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697878800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697878992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696078928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696079888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697880528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979697880720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696079696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696080848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696081616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696079120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696080272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696081808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696080656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696082768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696082192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696083152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696085072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696083536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696084304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696085264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696086224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696086992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696082576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696085648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696088144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696086032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696087568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696089104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696087952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696089488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696090448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696091216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696092368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696090832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696091600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696091792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696094672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696093712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696489296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696094480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696490064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696491024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696490448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696492176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696493328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696491792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696492560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696492752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696494864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696495632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696494672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696494480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696495824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696496784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696497552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696494288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696496208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696496592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696498704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696499088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696499856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696501008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696499472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696500240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696501200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696502160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696502928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696501968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696947472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696948240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696948048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696949584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696950736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696949968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696950160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696952272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696953040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696952080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696951888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983078433296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066922256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066922064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066921680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066909776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066922832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066918992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066920912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066920528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066920144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066916688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066916496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066919952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066917648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066918416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066916304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066917456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066918224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066914768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066915536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066911696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066914576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066914192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066916880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139983066913616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957785744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957777296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957786512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957776144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957774416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957772880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957785360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957774032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696951696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696953616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696954192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696954576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696954768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696954384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696955728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696955152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696956112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696956880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696958032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696956496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696957264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696957456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696959568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696960336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696959376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696959184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696961488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696962256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696958992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696962448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139979696961296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957674576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957689744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957688592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957689360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957690128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957689936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957687056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957688016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957687440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957686864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957685136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957686480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957684944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957686096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957683216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957684560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957682448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957682256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957679376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957680336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957679184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957677456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957676688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957678800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957677264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957678416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957675344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957676496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957675152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957674960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957120592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957121168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957123472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957123280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957124048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139982957126544: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# # Save the model architecture to JSON
# model_json = model.to_json()
# with open(os.path.join(MODEL_DIR, 'model_architecture.json'), 'w') as json_file:
#     json_file.write(model_json)
# print("Model architecture saved successfully.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/stepp
